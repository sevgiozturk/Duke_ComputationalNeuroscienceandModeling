# %%
# https://www.kaggle.com/code/nirajvermafcb/principal-component-analysis-with-scikit-learn/notebook

import pandas as pd
#from google.colab import drive
#drive.mount('/content/drive')


data = pd.read_csv('/content/drive/MyDrive/postDoc/hullLab/summercourse_ComputationalNeuroscienceandModeling/Duke_ComputationalNeuroscienceandModeling/w4/data.csv')

# %%
data.head()
# Out:
#    number_people                       date  timestamp  day_of_week  \
# 0             37  2015-08-14 17:00:11-07:00      61211            4
# 1             45  2015-08-14 17:20:14-07:00      62414            4
# 2             40  2015-08-14 17:30:15-07:00      63015            4
# 3             44  2015-08-14 17:40:16-07:00      63616            4
# 4             45  2015-08-14 17:50:17-07:00      64217            4
#
#    is_weekend  is_holiday  temperature  is_start_of_semester  \
# 0           0           0        71.76                     0
# 1           0           0        71.76                     0
# 2           0           0        71.76                     0
# 3           0           0        71.76                     0
# 4           0           0        71.76                     0
#
#    is_during_semester  month  hour
# 0                   0      8    17
# 1                   0      8    17
# 2                   0      8    17
# 3                   0      8    17
# ...
