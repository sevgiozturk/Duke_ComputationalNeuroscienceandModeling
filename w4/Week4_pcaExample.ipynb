# %%
# https://www.kaggle.com/code/nirajvermafcb/principal-component-analysis-with-scikit-learn/notebook

import pandas as pd
#from google.colab import drive
#drive.mount('/content/drive')


df = pd.read_csv('/content/drive/MyDrive/postDoc/hullLab/summercourse_ComputationalNeuroscienceandModeling/Duke_ComputationalNeuroscienceandModeling/w4/data.csv')

# %%
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-c42a15b2c7cf> in <cell line: 1>()
# ----> 1 df.head()
#
# NameError: name 'df' is not defined

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X = df.iloc[:,1:8]
X=scaler.fit_transform(X)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8562a0d2cef3> in <cell line: 3>()
#       1 from sklearn.preprocessing import StandardScaler
#       2 scaler = StandardScaler()
# ----> 3 X=scaler.fit_transform(X)
#
# NameError: name 'X' is not defined
